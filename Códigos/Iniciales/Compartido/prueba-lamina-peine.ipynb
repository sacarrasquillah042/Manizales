# %%
# %config InlineBackend.figure_formats = {"retina", "png"}
# %matplotlib inline

# %%
import os
os.environ["OPENBLAS_NUM_THREADS"] = "1"
import tempfile

from IPython.display import HTML, display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import h5py

import tdgl
from tdgl.geometry import box, circle

# %%
tempdir = tempfile.TemporaryDirectory(dir=os.getcwd())

# %% [markdown]
# # Definición de parámetros del material y de la geometría de peine asimétrico
#
# La geometría sigue la Ec. (1) del paper:
# $$y(x) = -h_d \sum_{i=1}^{N} \exp\left(-\frac{(x - x_i)^2}{2\delta^2}\right)$$
#
# donde:
# - $h_d$ = profundidad máxima de los dientes
# - $x_i$ = posición central del i-ésimo diente
# - $\delta = 0.20 \cdot \Delta x$ = parámetro de suavidad geométrica
# - $N$ = número de dientes (controla la densidad del peine)

# %%
length_units = "um"

# ─────────────────────────────────────────────
# PARÁMETROS DEL MATERIAL (sin cambios)
# ─────────────────────────────────────────────
xi            = 0.5   # Longitud de coherencia (µm)
london_lambda = 2     # Longitud de penetración de London (µm)
d             = 0.1   # Espesor de la lámina (µm)
gamma         = 1     # Parámetro de amortiguamiento

layer = tdgl.Layer(
    coherence_length=xi,
    london_lambda=london_lambda,
    thickness=d,
    gamma=gamma
)

# ─────────────────────────────────────────────
# PARÁMETROS GEOMÉTRICOS GLOBALES DEL DISPOSITIVO
# Según el paper: Lx = 20 µm, Ly = 5 µm, Lz = 0.1 µm
# ─────────────────────────────────────────────
total_length = 20.0   # Lx: longitud total del dispositivo (µm)
total_width  = 5.0    # Ly: altura del bloque rectangular base (µm)

# ─────────────────────────────────────────────
# PARÁMETROS DE LOS DIENTES GAUSSIANOS (Ec. 1 del paper)
# ─────────────────────────────────────────────
N  = 8      # Número de dientes (probar: 4, 8, 12, 16)
hd = 3.5    # Profundidad máxima de cada diente (µm)
            # Nota: hd < total_width para que el dispositivo no quede cerrado

# Separación entre dientes: se distribuyen uniformemente a lo largo de Lx
delta_x = total_length / N          # Separación entre centros de dientes (µm)
delta   = 0.20 * delta_x            # Parámetro de suavidad geométrica (δ = 0.20·Δx)

# Posiciones centrales de cada diente xi, distribuidas uniformemente
# Se centra el primer y último diente a media separación del borde
x_teeth = np.linspace(
    -total_length / 2 + delta_x / 2,
     total_length / 2 - delta_x / 2,
    N
)

print(f"Número de dientes    N  = {N}")
print(f"Separación entre dientes Δx = {delta_x:.3f} µm")
print(f"Parámetro de suavidad    δ  = {delta:.3f} µm")
print(f"Profundidad de dientes   hd = {hd} µm")
print(f"Posiciones xi = {np.round(x_teeth, 2)}")

# ─────────────────────────────────────────────
# FUNCIÓN DEL PERFIL DEL BORDE INFERIOR (Ec. 1)
# y(x) = -hd * Σ exp(-(x - xi)^2 / (2δ^2))
# ─────────────────────────────────────────────
def lower_edge_profile(x, hd, x_teeth, delta):
    """Perfil del borde inferior con dientes gaussianos (Ec. 1 del paper)."""
    y = np.zeros_like(x, dtype=float)
    for xi_i in x_teeth:
        y += -hd * np.exp(-((x - xi_i) ** 2) / (2 * delta ** 2))
    return y

# ─────────────────────────────────────────────
# CONSTRUCCIÓN DEL POLÍGONO DE PEINE ASIMÉTRICO
# El polígono recorre: borde superior (recto) → lado derecho → 
#   borde inferior con dientes → lado izquierdo → cierre
# ─────────────────────────────────────────────
n_points = 1000  # Resolución del borde inferior (más puntos = dientes más suaves)

x_bottom = np.linspace(-total_length / 2, total_length / 2, n_points)
y_bottom = lower_edge_profile(x_bottom, hd, x_teeth, delta)

# El borde inferior tiene coordenadas y en [-total_width/2 + y_diente]
# El borde superior está en y = +total_width/2 (recto, sin dientes)
y_top    =  total_width / 2
y_base   = -total_width / 2   # Línea base del borde inferior sin dientes

# El perfil gaussiano desplaza el borde inferior hacia abajo desde y_base
y_bottom_coords = y_base + y_bottom  # y_bottom es negativo → borde baja

# Ensamblar el contorno completo del polígono (sentido antihorario)
#   1. Borde superior: de izquierda a derecha
#   2. Lado derecho: baja de y_top a y_base
#   3. Borde inferior con dientes: de derecha a izquierda
#   4. Lado izquierdo: sube de y_base a y_top
x_top_edge    = np.array([-total_length/2, total_length/2])
y_top_edge    = np.array([y_top, y_top])

x_right_edge  = np.array([total_length/2, total_length/2])
y_right_edge  = np.array([y_top, y_base])

# Borde inferior (de derecha a izquierda, para cerrar el polígono)
x_bot_rev     = x_bottom[::-1]
y_bot_rev     = y_bottom_coords[::-1]

x_left_edge   = np.array([-total_length/2, -total_length/2])
y_left_edge   = np.array([y_base, y_top])

# Concatenar todos los segmentos
x_polygon = np.concatenate([x_top_edge, x_right_edge, x_bot_rev, x_left_edge])
y_polygon = np.concatenate([y_top_edge, y_right_edge, y_bot_rev, y_left_edge])

polygon_points = np.column_stack([x_polygon, y_polygon])

# ─────────────────────────────────────────────
# FILM: Polígono de peine asimétrico
# ─────────────────────────────────────────────
film = (
    tdgl.Polygon("film", points=polygon_points)
    .resample(1200)   # Mayor resolución para capturar bien los dientes
    .buffer(0)
)

# ─────────────────────────────────────────────
# TERMINALES: Source (izquierda) y Drain (derecha)
# Longitud del contacto = 2.0 µm según el paper
# ─────────────────────────────────────────────
contact_length = 2.0   # Longitud de los contactos metálicos (µm), según el paper
contact_width  = 0.1   # Ancho del contacto en x (µm)

source = (
    tdgl.Polygon("source", points=box(contact_width, contact_length))
    .translate(dx=-total_length / 2)
)

drain = source.scale(xfact=-1).set_name("drain")

# ─────────────────────────────────────────────
# PUNTOS DE MEDICIÓN DE VOLTAJE
# ─────────────────────────────────────────────
probe_points = [
    (-total_length / 2.5, 0),
     (total_length / 2.5, 0)
]

# ─────────────────────────────────────────────
# DEFINICIÓN DEL DISPOSITIVO
# ─────────────────────────────────────────────
device = tdgl.Device(
    "peine_asimetrico",
    layer=layer,
    film=film,
    terminals=[source, drain],
    probe_points=probe_points,
    length_units=length_units,
)

print("\nDispositivo creado correctamente.")
# Out:
# Número de dientes    N  = 8
# Separación entre dientes Δx = 2.500 µm
# Parámetro de suavidad    δ  = 0.500 µm
# Profundidad de dientes   hd = 3.5 µm
# Posiciones xi = [-8.75 -6.25 -3.75 -1.25  1.25  3.75  6.25  8.75]
#
# Dispositivo creado correctamente.

# %%
# Visualizar el perfil del borde inferior antes de crear el dispositivo
fig, ax = plt.subplots(figsize=(10, 3))
x_plot = np.linspace(-total_length / 2, total_length / 2, 2000)
y_plot = y_base + lower_edge_profile(x_plot, hd, x_teeth, delta)
ax.plot(x_plot, y_plot, 'b-', label='Borde inferior (dientes)')
ax.axhline(y_top, color='r', linestyle='--', label='Borde superior')
ax.fill_between(x_plot, y_plot, y_top, alpha=0.15, color='gray')
for xi_i in x_teeth:
    ax.axvline(xi_i, color='g', linestyle=':', alpha=0.5, linewidth=0.8)
ax.set_xlabel('x (µm)')
ax.set_ylabel('y (µm)')
ax.set_title(f'Geometría de peine asimétrico — N={N} dientes, hd={hd} µm, δ={delta:.2f} µm')
ax.legend()
ax.set_aspect('equal')
plt.tight_layout()
plt.show()

# %%
# Dibujar el dispositivo con tdgl
fig, ax = device.draw()

# %%
# ─────────────────────────────────────────────
# OPCIONES DEL SOLVER (sin cambios)
# ─────────────────────────────────────────────
options = tdgl.SolverOptions(
    skip_time=100,
    solve_time=200,
    output_file=os.path.join(tempdir.name, "campo_corriente_peine.h5"),
    field_units="mT",
    current_units="uA",
    save_every=100,
)

# %%
# Generar la malla del dispositivo
device.make_mesh(max_edge_length=xi / 2, smooth=100)
fig, ax = device.plot(mesh=True, legend=True)
# Out:
# Constructing Voronoi polygons: 100%|██████████| 9252/9252 [00:00<00:00, 12422.42it/s]

# %% [markdown]
# # Simulación de las corrientes en el superconductor de peine
#
# - I = 12 µA
# - H = 0

# %%
default_terminal_currents = {
    'source':  12,
    'drain':  -12
}

H_zero_solution = tdgl.solve(
    device=device,
    options=options,
    terminal_currents=default_terminal_currents
)

fig, axes = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)
_ = H_zero_solution.plot_currents(ax=axes[0], streamplot=False)
_ = H_zero_solution.plot_currents(ax=axes[1])

# Sección transversal vertical en el centro del dispositivo
y_cross = np.linspace(-total_width / 2, total_width / 2, 401)
x_cross = np.zeros_like(y_cross)
cross_section = np.array([x_cross, y_cross]).T

for ax in axes:
    _ = ax.plot(x_cross, y_cross, "C1--")

current = H_zero_solution.current_through_path(cross_section)
print(f"Corriente medida: {current:.3f~P}")
# Out:
# Thermalizing: 100%|█████████▉| 100/100 [00:09<00:00, 10.40tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:12<00:00, 15.98tau/s ]
# Corriente medida: 10.795 µA

# %%
# ─────────────────────────────────────────────
# BARRIDO DE CORRIENTE: Curva V vs I
# ─────────────────────────────────────────────
def get_mean_voltage(device, options, current):
    terminal_currents = {
        'source':  current,
        'drain':  -current
    }
    solution = tdgl.solve(
        device=device,
        options=options,
        terminal_currents=terminal_currents
    )
    voltage = solution.dynamics.mean_voltage()
    return voltage

currents = np.arange(0.0, 50, 0.1)
voltages = []
intensities = []

voltage_current_csv_filename = "V_vs_I_peine.csv"
csv_path = os.path.join("raw_data", voltage_current_csv_filename)

if os.path.exists(csv_path):
    os.remove(csv_path)

for current in currents:
    voltage = get_mean_voltage(device=device, options=options, current=current)
    voltages.append(voltage)
    intensities.append(current)

    csv_df = pd.DataFrame({'current_µA': [current], 'voltage_V': [voltage]})
    csv_df.to_csv(csv_path, mode='a', header=not os.path.exists(csv_path), index=False)
# Out:
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-1.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:07<00:00, 12.96tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:09<00:00, 21.86tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-2.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  7.07tau/s ]
# Simulating: 100%|██████████| 200/200 [00:24<00:00,  8.23tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-3.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.38tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.14tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-4.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.55tau/s ]
# Simulating: 100%|██████████| 200/200 [00:24<00:00,  8.33tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-5.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.88tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.88tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-6.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  7.75tau/s ]
# Simulating: 100%|██████████| 200/200 [00:25<00:00,  7.91tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-7.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  7.03tau/s ]
# Simulating: 100%|██████████| 200/200 [00:25<00:00,  7.81tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-8.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.21tau/s ]
# Simulating: 100%|██████████| 200/200 [00:26<00:00,  7.59tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-9.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.24tau/s ]
# Simulating: 100%|██████████| 200/200 [00:26<00:00,  7.67tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-10.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.20tau/s ]
# Simulating: 100%|██████████| 200/200 [00:26<00:00,  7.66tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-11.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.78tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.99tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-12.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.93tau/s ]
# Simulating: 100%|██████████| 200/200 [00:26<00:00,  7.65tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-13.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.18tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.75tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-14.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  7.02tau/s ]
# Simulating: 100%|██████████| 200/200 [00:26<00:00,  7.60tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-15.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.40tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.77tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-16.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  7.13tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.79tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-17.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.96tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.73tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-18.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.76tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:26<00:00,  7.58tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-19.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.86tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.93tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-20.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  7.13tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.25tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-21.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.99tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.83tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-22.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.79tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.91tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-23.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.16tau/s ]
# Simulating: 100%|██████████| 200/200 [00:25<00:00,  7.79tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-24.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.93tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.11tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-25.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.24tau/s ]
# Simulating: 100%|██████████| 200/200 [00:25<00:00,  7.90tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-26.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.40tau/s ]
# Simulating: 100%|██████████| 200/200 [00:25<00:00,  7.97tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-27.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.21tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.74tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-28.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.97tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.19tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-29.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.37tau/s ]
# Simulating: 100%|██████████| 200/200 [00:24<00:00,  8.27tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-30.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.99tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.09tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-31.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.51tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.19tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-32.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.29tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.12tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-33.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.19tau/s ]
# Simulating: 100%|██████████| 200/200 [00:24<00:00,  8.19tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-34.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.92tau/s ]
# Simulating: 100%|██████████| 200/200 [00:23<00:00,  8.46tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-35.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.17tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:23<00:00,  8.48tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-36.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.17tau/s ]
# Simulating: 100%|██████████| 200/200 [00:23<00:00,  8.50tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-37.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.52tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:23<00:00,  8.62tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-38.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.36tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:23<00:00,  8.57tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-39.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.59tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:23<00:00,  8.60tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-40.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.57tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.30tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-41.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  7.14tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:23<00:00,  8.33tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-42.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.49tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.02tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-43.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  7.83tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:23<00:00,  8.60tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-44.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.62tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:23<00:00,  8.41tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-45.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.55tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.12tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-46.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.38tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.01tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-47.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.19tau/s ]
# Simulating: 100%|██████████| 200/200 [00:23<00:00,  8.58tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-48.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.44tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.17tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-49.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  7.75tau/s ]
# Simulating: 100%|██████████| 200/200 [00:22<00:00,  8.82tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-50.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.15tau/s ]
# Simulating: 100%|██████████| 200/200 [00:24<00:00,  8.12tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-51.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.64tau/s ]
# Simulating: 100%|██████████| 200/200 [00:25<00:00,  7.86tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-52.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.83tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.27tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-53.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.24tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.02tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-54.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  7.82tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.14tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-55.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  7.10tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.01tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-56.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.30tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.98tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-57.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.28tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:23<00:00,  8.51tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-58.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.28tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.24tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-59.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.21tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.99tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-60.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  7.08tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.95tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-61.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  7.11tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.75tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-62.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.98tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.89tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-63.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.23tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.09tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-64.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  7.13tau/s ]
# Simulating: 100%|██████████| 200/200 [00:24<00:00,  8.07tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-65.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.32tau/s ]
# Simulating: 100%|██████████| 200/200 [00:25<00:00,  7.71tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-66.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:15<00:00,  6.59tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.97tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-67.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  7.08tau/s ]
# Simulating: 100%|██████████| 200/200 [00:25<00:00,  7.72tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-68.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  7.06tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.18tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-69.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.16tau/s ]
# Simulating: 100%|██████████| 200/200 [00:25<00:00,  7.76tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-70.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  7.11tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:24<00:00,  8.01tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-71.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.23tau/s ]
# Simulating: 100%|██████████| 200/200 [00:25<00:00,  7.77tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-72.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:15<00:00,  6.57tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:25<00:00,  7.76tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-73.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.83tau/s ]
# Simulating: 100%|██████████| 200/200 [00:26<00:00,  7.62tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-74.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:14<00:00,  6.97tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:22<00:00,  8.84tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-75.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:13<00:00,  7.24tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:22<00:00,  9.07tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-76.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  7.81tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:21<00:00,  9.42tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-77.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  7.96tau/s ]
# Simulating: 100%|██████████| 200/200 [00:21<00:00,  9.35tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-78.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.40tau/s ]
# Simulating: 100%|██████████| 200/200 [00:21<00:00,  9.43tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-79.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  8.04tau/s ]
# Simulating: 100%|██████████| 200/200 [00:19<00:00, 10.31tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-80.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  8.07tau/s ]
# Simulating: 100%|██████████| 200/200 [00:18<00:00, 10.55tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-81.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.40tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:18<00:00, 10.59tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-82.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.68tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:17<00:00, 11.18tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-83.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.45tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:17<00:00, 11.49tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-84.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.51tau/s ]
# Simulating: 100%|██████████| 200/200 [00:17<00:00, 11.13tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-85.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  9.03tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:18<00:00, 10.63tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-86.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  7.90tau/s ]
# Simulating: 100%|██████████| 200/200 [00:18<00:00, 11.00tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-87.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.56tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:17<00:00, 11.46tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-88.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.54tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:16<00:00, 11.99tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-89.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.78tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:17<00:00, 11.68tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-90.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.68tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:17<00:00, 11.63tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-91.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.77tau/s ]
# Simulating: 100%|██████████| 200/200 [00:17<00:00, 11.67tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-92.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.87tau/s ]
# Simulating: 100%|██████████| 200/200 [00:18<00:00, 10.92tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-93.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.60tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:18<00:00, 11.04tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-94.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.73tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:16<00:00, 11.87tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-95.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.66tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:16<00:00, 11.92tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-96.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.54tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:17<00:00, 11.58tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-97.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.49tau/s ]
# Simulating: 100%|██████████| 200/200 [00:16<00:00, 11.86tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-98.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.39tau/s ]
# Simulating: 100%|██████████| 200/200 [00:17<00:00, 11.54tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-99.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.86tau/s ]
# Simulating: 100%|██████████| 200/200 [00:16<00:00, 11.97tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-100.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.37tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:19<00:00, 10.39tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-101.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  8.29tau/s ]
# Simulating: 100%|██████████| 200/200 [00:15<00:00, 12.58tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-102.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.88tau/s ]
# Simulating: 100%|██████████| 200/200 [00:16<00:00, 12.32tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-103.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.39tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:17<00:00, 11.30tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-104.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.69tau/s ]
# Simulating: 100%|██████████| 200/200 [00:16<00:00, 12.46tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-105.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.51tau/s ]
# Simulating: 100%|██████████| 200/200 [00:15<00:00, 12.88tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-106.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.96tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 13.16tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-107.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.88tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:16<00:00, 12.20tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-108.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.83tau/s ]
# Simulating: 100%|██████████| 200/200 [00:16<00:00, 12.08tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-109.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  9.08tau/s ]
# Simulating: 100%|██████████| 200/200 [00:16<00:00, 12.46tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-110.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.98tau/s ]
# Simulating: 100%|██████████| 200/200 [00:15<00:00, 13.15tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-111.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.41tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.38tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-112.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.42tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 13.28tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-113.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.85tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 13.94tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-114.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.24tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 13.21tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-115.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.91tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 14.26tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-116.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.93tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:13<00:00, 14.39tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-117.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.75tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.95tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-118.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.08tau/s ]
# Simulating: 100%|██████████| 200/200 [00:15<00:00, 12.98tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-119.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.60tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:13<00:00, 14.62tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-120.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.46tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 13.63tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-121.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.86tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:13<00:00, 14.90tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-122.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:09<00:00, 10.15tau/s ]
# Simulating: 100%|██████████| 200/200 [00:13<00:00, 15.11tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-123.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.42tau/s ]
# Simulating: 100%|██████████| 200/200 [00:13<00:00, 14.80tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-124.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:09<00:00, 10.42tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 14.24tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-125.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.28tau/s ]
# Simulating: 100%|██████████| 200/200 [00:13<00:00, 14.99tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-126.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.23tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:13<00:00, 14.63tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-127.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.57tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:13<00:00, 14.66tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-128.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.80tau/s ]
# Simulating: 100%|██████████| 200/200 [00:12<00:00, 15.52tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-129.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.67tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:13<00:00, 15.01tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-130.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.44tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:13<00:00, 14.31tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-131.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.41tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.70tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-132.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.23tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:13<00:00, 15.29tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-133.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.24tau/s ]
# Simulating: 100%|██████████| 200/200 [00:13<00:00, 14.45tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-134.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.16tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 14.20tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-135.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.26tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 14.24tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-136.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  9.07tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:13<00:00, 14.94tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-137.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  9.04tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.98tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-138.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.27tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.89tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-139.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.38tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 14.19tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-140.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.33tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 14.07tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-141.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.29tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 13.65tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-142.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.24tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.49tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-143.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.56tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 13.94tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-144.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.19tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.69tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-145.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.10tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.47tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-146.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.92tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 13.17tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-147.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.95tau/s ]
# Simulating: 100%|██████████| 200/200 [00:15<00:00, 13.25tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-148.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.71tau/s ]
# Simulating: 100%|██████████| 200/200 [00:15<00:00, 12.78tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-149.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  8.28tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 12.85tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-150.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.64tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 13.31tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-151.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.51tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 12.98tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-152.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.73tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 13.13tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-153.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.67tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 13.32tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-154.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.17tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 13.37tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-155.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.89tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 13.12tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-156.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.92tau/s ]
# Simulating: 100%|██████████| 200/200 [00:16<00:00, 12.31tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-157.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  8.31tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:16<00:00, 12.44tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-158.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  8.24tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 13.45tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-159.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.66tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.71tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-160.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.73tau/s ]
# Simulating: 100%|██████████| 200/200 [00:16<00:00, 11.91tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-161.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.65tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.65tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-162.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.97tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 13.64tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-163.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.78tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 12.60tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-164.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.76tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 13.20tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-165.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.68tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 13.21tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-166.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.15tau/s ]
# Simulating: 100%|██████████| 200/200 [00:15<00:00, 12.72tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-167.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.43tau/s ]
# Simulating: 100%|██████████| 200/200 [00:15<00:00, 12.58tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-168.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.47tau/s ]
# Simulating: 100%|██████████| 200/200 [00:15<00:00, 13.30tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-169.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.99tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 13.22tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-170.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.98tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.38tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-171.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.77tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.54tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-172.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.86tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 13.55tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-173.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.11tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.50tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-174.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.73tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.47tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-175.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.72tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 13.69tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-176.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  9.02tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.57tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-177.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  9.02tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 13.10tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-178.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.61tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 12.93tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-179.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:12<00:00,  7.93tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.42tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-180.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.70tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 14.03tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-181.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.97tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 14.14tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-182.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  9.08tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.81tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-183.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:10<00:00,  9.21tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 14.07tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-184.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  9.07tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 14.07tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-185.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.70tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:15<00:00, 13.09tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-186.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  9.06tau/s ]
# Simulating: 100%|██████████| 200/200 [00:14<00:00, 13.60tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-187.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.93tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:14<00:00, 13.69tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-188.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:11<00:00,  8.88tau/s ]
# ...
# Simulating: 100%|█████████▉| 200/200 [00:38<00:00,  5.24tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-439.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:24<00:00,  4.11tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:37<00:00,  5.28tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-440.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:24<00:00,  4.11tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:37<00:00,  5.28tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-441.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:24<00:00,  4.13tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:37<00:00,  5.30tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-442.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:24<00:00,  4.15tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:37<00:00,  5.33tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-443.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:24<00:00,  4.14tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:37<00:00,  5.33tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-444.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:24<00:00,  4.14tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:37<00:00,  5.37tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-445.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:24<00:00,  4.15tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:37<00:00,  5.37tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-446.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:24<00:00,  4.15tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:37<00:00,  5.37tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-447.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.17tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:36<00:00,  5.43tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-448.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.17tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:36<00:00,  5.42tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-449.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.19tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:36<00:00,  5.42tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-450.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.22tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:36<00:00,  5.46tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-451.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.19tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:36<00:00,  5.44tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-452.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.20tau/s ]
# Simulating: 100%|██████████| 200/200 [00:36<00:00,  5.47tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-453.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.20tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:36<00:00,  5.47tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-454.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.24tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:36<00:00,  5.51tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-455.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.24tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:36<00:00,  5.54tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-456.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.24tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:35<00:00,  5.57tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-457.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.23tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:35<00:00,  5.57tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-458.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.27tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:35<00:00,  5.59tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-459.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.26tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:35<00:00,  5.62tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-460.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.28tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:35<00:00,  5.64tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-461.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.28tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:35<00:00,  5.63tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-462.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.29tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:35<00:00,  5.65tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-463.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.30tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:35<00:00,  5.68tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-464.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.32tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:35<00:00,  5.68tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-465.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.32tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:34<00:00,  5.74tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-466.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.31tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:34<00:00,  5.72tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-467.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.33tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:34<00:00,  5.76tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-468.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.34tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:34<00:00,  5.78tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-469.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:23<00:00,  4.35tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:34<00:00,  5.76tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-470.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.35tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:34<00:00,  5.83tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-471.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.36tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:34<00:00,  5.84tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-472.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.37tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:34<00:00,  5.85tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-473.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.36tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:34<00:00,  5.86tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-474.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.39tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:33<00:00,  5.88tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-475.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.38tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:33<00:00,  5.92tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-476.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.40tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:33<00:00,  5.91tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-477.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.41tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:33<00:00,  5.94tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-478.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.42tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:33<00:00,  5.93tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-479.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.42tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:33<00:00,  5.99tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-480.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.41tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:33<00:00,  6.01tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-481.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.43tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:33<00:00,  6.01tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-482.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.44tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:33<00:00,  6.06tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-483.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.47tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:32<00:00,  6.06tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-484.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.47tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:32<00:00,  6.08tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-485.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.47tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:32<00:00,  6.09tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-486.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.48tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:32<00:00,  6.13tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-487.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.48tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:32<00:00,  6.13tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-488.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.49tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:32<00:00,  6.15tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-489.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.49tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:32<00:00,  6.17tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-490.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.50tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:32<00:00,  6.19tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-491.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.50tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:32<00:00,  6.22tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-492.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.52tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:32<00:00,  6.20tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-493.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.52tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:31<00:00,  6.26tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-494.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.53tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:32<00:00,  6.25tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-495.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.53tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:31<00:00,  6.30tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-496.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.53tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:31<00:00,  6.30tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-497.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:22<00:00,  4.54tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:31<00:00,  6.32tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-498.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:21<00:00,  4.55tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:31<00:00,  6.36tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-499.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:21<00:00,  4.56tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:31<00:00,  6.39tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpil2og10z/campo_corriente_peine-500.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:21<00:00,  4.56tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:31<00:00,  6.40tau/s ]

# %%
df = pd.read_csv(csv_path)
arr = df.to_numpy()

voltages    = [a[1] for a in arr]
intensities = [a[0] for a in arr]

plt.figure(figsize=(6, 4))
plt.plot(intensities, voltages, linestyle='-', color='blue')
plt.xlabel('Corriente (µA)')
plt.ylabel('Voltaje promedio (V)')
plt.title(f'Curva V-I — Peine asimétrico N={N}')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.plot(intensities[:300], voltages[:300], linestyle='-', color='blue')
plt.xlabel('Corriente (µA)')
plt.ylabel('Voltaje promedio (V)')
plt.title(f'Curva V-I (primeros 300 puntos) — N={N}')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.plot(intensities[:240], voltages[:240], color='blue')
plt.xlabel('Corriente (µA)')
plt.ylabel('Voltaje promedio (V)')
plt.title(f'Curva V-I (primeros 240 puntos) — N={N}')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# ─────────────────────────────────────────────
# DETECCIÓN DE LA CORRIENTE CRÍTICA
# Criterio: mayor salto (gap) consecutivo en voltaje
# ─────────────────────────────────────────────
critical_current = 0
biggest_gap = 0

for i in range(len(voltages) - 1):
    tmp_gap = voltages[i + 1] - voltages[i]
    if tmp_gap > biggest_gap:
        biggest_gap = tmp_gap
        critical_current = i

plt.figure(figsize=(6, 4))
plt.plot(intensities[220:280], voltages[220:280], linestyle='-', color='blue')
plt.axvline(
    currents[critical_current],
    label=f'Corriente crítica: {currents[critical_current]:.2f} µA'
)
plt.xlabel('Corriente (µA)')
plt.ylabel('Voltaje promedio (V)')
plt.title(f'Corriente crítica — Peine N={N}')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

print(f"Corriente crítica estimada: {currents[critical_current]:.2f} µA")
# Out:
# Corriente crítica estimada: 27.70 µA
