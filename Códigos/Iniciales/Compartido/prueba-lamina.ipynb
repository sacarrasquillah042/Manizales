# %%
# %config InlineBackend.figure_formats = {"retina", "png"}
# %matplotlib inline

# %%
import os
os.environ["OPENBLAS_NUM_THREADS"] = "1"
import tempfile

from IPython.display import HTML, display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import h5py

import tdgl
from tdgl.geometry import box, circle

# %%
tempdir = tempfile.TemporaryDirectory(dir=os.getcwd())

# %%
length_units = "um" 

# Material Parameters
xi = 0.5
london_lambda = 2
d = 0.1
layer = tdgl.Layer(coherence_length=xi, london_lambda=london_lambda, thickness=d, gamma=1)

# Device geometry
total_width = 10
total_length = 5
link_width = total_width / 3

# Rectangle
film = (
    tdgl.Polygon("film", points=box(total_width, total_length))
    .resample(401)
    .buffer(0)
)

# Source
source = (
    tdgl.Polygon("source", points=box(total_width / 100, 0.3 * total_length))
    .translate(dx=-total_width / 2)
)

# drain
drain = source.scale(xfact=-1).set_name("drain")

#  Voltage measurement points
probe_points = [(-total_width / 2.5, 0), (total_width / 2.5, 0)]

# Define device 
device = tdgl.Device(
    "plate",
    layer=layer,
    film=film,
    terminals=[source, drain],
    probe_points=probe_points,
    length_units=length_units,
)

# %%
fig, ax = device.draw()

# %%
# options for solver
options = tdgl.SolverOptions(
    skip_time=100,
    solve_time=200,
    output_file=os.path.join(tempdir.name, "campo_corriente.h5"),
    field_units="mT",
    current_units="uA",
    save_every=100,
)

# %%
# make mesh
device.make_mesh(max_edge_length=xi/2, smooth=100)
# Out:
# Constructing Voronoi polygons: 100%|██████████| 3206/3206 [00:00<00:00, 12449.41it/s]

# %%
fig, ax = device.plot(mesh=True, legend=True)

# %% [markdown]
# # Simulación de las corrientes en el supercondutor
#
# - I = 12 µA
# - H = 0

# %%
default_terminal_currents = {
    'source': 12,
    'drain': -12
}

H_zero_solution = tdgl.solve(device=device, options=options, terminal_currents=default_terminal_currents)

fig, axes = plt.subplots(1, 2, figsize=(9,4), constrained_layout= True)
_ = H_zero_solution.plot_currents(ax=axes[0], streamplot = False)
_ = H_zero_solution.plot_currents(ax=axes[1])

y = np.linspace(-total_width / 2, total_width / 2, 401)
x = np.zeros_like(y)

cross_section = np.array([x, y]).T

# Cross section draw
for ax in axes:
    _ = ax.plot(x, y, "C1--")

# current flux alongside cross section
current = H_zero_solution.current_through_path(cross_section)
print(f"Measured current: {current:.3f~P}")
# Out:
# Thermalizing: 100%|█████████▉| 100/100 [00:03<00:00, 25.91tau/s ]
# Simulating: 100%|██████████| 200/200 [00:05<00:00, 35.41tau/s ]
# Measured current: 11.745 µA

# %%
# Graph current vs voltage
def get_mean_voltage(device, options, current):
  terminal_currents = {
      'source': current,
      'drain': -current
  }

  solution = tdgl.solve(device=device, options=options, terminal_currents=terminal_currents)
  voltage = solution.dynamics.mean_voltage()
  return voltage

currents = np.arange(0.0, 50, 0.1)
voltages = []
intensities = []

voltage_current_csv_filename = "V_vs_I_lámina.csv"
csv_path = os.path.join("raw_data", voltage_current_csv_filename)

if os.path.exists(csv_path):
    os.remove(csv_path)

for current in currents:
    voltage = get_mean_voltage(device=device, options=options, current=current)
    voltages.append(voltage)
    intensities.append(current)
  
    csv_df = pd.DataFrame({'current_µA': [current], 'voltage_V': [voltage]})
    csv_df.to_csv(csv_path, mode='a', header=not os.path.exists(csv_path), index=False)
# Out:
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-1.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:03<00:00, 32.98tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:03<00:00, 57.19tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-2.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 19.08tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:09<00:00, 21.07tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-3.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 18.12tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:10<00:00, 19.27tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-4.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 17.84tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:10<00:00, 19.07tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-5.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 18.29tau/s ]
# Simulating: 100%|██████████| 200/200 [00:10<00:00, 19.94tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-6.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 18.68tau/s ]
# Simulating: 100%|██████████| 200/200 [00:10<00:00, 19.82tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-7.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 17.65tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:10<00:00, 19.28tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-8.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 18.25tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:10<00:00, 19.21tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-9.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 17.88tau/s ]
# Simulating: 100%|██████████| 200/200 [00:09<00:00, 20.06tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-10.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 17.99tau/s ]
# Simulating: 100%|██████████| 200/200 [00:10<00:00, 18.40tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-11.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 17.88tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:10<00:00, 19.45tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-12.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 17.93tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:10<00:00, 19.49tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-13.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 17.53tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:10<00:00, 19.00tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-14.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 17.70tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:10<00:00, 18.86tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-15.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 17.52tau/s ]
# Simulating: 100%|██████████| 200/200 [00:10<00:00, 19.24tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-16.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 17.90tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:10<00:00, 19.42tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-17.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 17.44tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:10<00:00, 19.43tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-18.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 16.97tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:10<00:00, 19.64tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-19.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:05<00:00, 17
au/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-158.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:03<00:00, 25.10tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.45tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-159.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 23.97tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.37tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-160.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.69tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.25tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-161.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.89tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.27tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-162.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:03<00:00, 25.17tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 37.13tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-163.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.95tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.07tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-164.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.15tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.72tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-165.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.82tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.79tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-166.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.40tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.25tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-167.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.47tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.21tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-168.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.35tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.44tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-169.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 23.77tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 35.84tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-170.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.48tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 35.04tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-171.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.05tau/s ]
# Simulating: 100%|██████████| 200/200 [00:05<00:00, 36.53tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-172.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.49tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 37.10tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-173.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.65tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 38.05tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-174.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.50tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.81tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-175.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.33tau/s ]
# Simulating: 100%|██████████| 200/200 [00:05<00:00, 36.87tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-176.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 23.87tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.81tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-177.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.56tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 37.69tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-178.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.20tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 37.87tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-179.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.48tau/s ]
# Simulating: 100%|██████████| 200/200 [00:05<00:00, 37.70tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-180.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.21tau/s ]
# Simulating: 100%|██████████| 200/200 [00:05<00:00, 37.28tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-181.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.47tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 37.53tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-182.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.48tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 38.04tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-183.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 24.42tau/s ]
# Simulating: 100%|██████████| 200/200 [00:05<00:00, 36.20tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-184.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 22.98tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 38.59tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-185.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 23.79tau/s ]
# Simulating: 100%|██████████| 200/200 [00:05<00:00, 37.37tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-186.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 23.91tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 37.93tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-187.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 23.83tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 37.27tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-188.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 23.62tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 37.37tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-189.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 22.74tau/s ]
# Simulating: 100%|██████████| 200/200 [00:05<00:00, 36.20tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-190.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 22.78tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.62tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-191.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 23.54tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.79tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-192.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:04<00:00, 22.99tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 36.72tau/s ]
# ...
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-437.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.39tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.88tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-438.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.37tau/s ]
# Simulating: 100%|██████████| 200/200 [00:05<00:00, 34.02tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-439.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.43tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 34.74tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-440.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.47tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.90tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-441.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.38tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.79tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-442.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.48tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.44tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-443.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.03tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.35tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-444.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.50tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 33.44tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-445.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.48tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.19tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-446.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.45tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.51tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-447.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.44tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.62tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-448.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.31tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.91tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-449.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.49tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.11tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-450.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.49tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 33.13tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-451.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.54tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 33.29tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-452.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.52tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.74tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-453.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.61tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.89tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-454.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.56tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 33.37tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-455.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.49tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.74tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-456.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.62tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.07tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-457.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.49tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.95tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-458.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.59tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.64tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-459.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.53tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.61tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-460.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.60tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.22tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-461.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.51tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 33.51tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-462.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.61tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 33.21tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-463.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.38tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.84tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-464.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.51tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.99tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-465.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.60tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.63tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-466.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.60tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.99tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-467.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.76tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.05tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-468.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.60tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.78tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-469.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.61tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.08tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-470.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.48tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.78tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-471.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.66tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.24tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-472.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.41tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.65tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-473.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.93tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.86tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-474.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.73tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.06tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-475.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.61tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.22tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-476.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.63tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.45tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-477.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.57tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.11tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-478.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.34tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.12tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-479.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.49tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.36tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-480.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.41tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.20tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-481.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.74tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.61tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-482.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.79tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 33.14tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-483.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.82tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 33.13tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-484.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.23tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.01tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-485.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.73tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.47tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-486.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.46tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:05<00:00, 33.43tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-487.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.73tau/s ]
# Simulating: 100%|██████████| 200/200 [00:05<00:00, 34.03tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-488.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.66tau/s ]
# Simulating: 100%|██████████| 200/200 [00:05<00:00, 33.62tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-489.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.56tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 33.05tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-490.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.64tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.61tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-491.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.48tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 33.13tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-492.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.74tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.00tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-493.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.49tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.64tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-494.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.59tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.25tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-495.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.89tau/s ]
# Simulating: 100%|██████████| 200/200 [00:06<00:00, 32.85tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-496.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 16.12tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.07tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-497.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.50tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.94tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-498.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.37tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.22tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-499.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 15.90tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 33.05tau/s ]
# Output file already exists. Renaming to /home/sergio/Documentos/Congreso/Programa 3/tmpaepw0ux3/campo_corriente-500.h5.
# Thermalizing: 100%|█████████▉| 100/100 [00:06<00:00, 16.01tau/s ]
# Simulating: 100%|█████████▉| 200/200 [00:06<00:00, 32.52tau/s ]

# %%
df = pd.read_csv(csv_path)
arr = df.to_numpy()

voltages = [a[1] for a in arr]
intensities = [a[0] for a in arr]

plt.figure(figsize=(6, 4))
plt.plot(intensities, voltages, linestyle='-', color='blue')
plt.xlabel('Corriente (µA)')
plt.ylabel('Voltaje promedio (V)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.plot(intensities[:300], voltages[:300], linestyle='-', color='blue')
plt.xlabel('Corriente (µA)')
plt.ylabel('Voltaje promedio (V)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.plot(intensities[:240], voltages[:240], color='blue')
plt.xlabel('Corriente (µA)')
plt.ylabel('Voltaje promedio (V)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
critical_current = 0
biggest_gap = 0

for i in range(len(voltages)-1):
    tmp_gap = voltages[i+1] - voltages[i]
    if tmp_gap >  biggest_gap:
        biggest_gap = tmp_gap
        critical_current = i


plt.figure(figsize=(6, 4))
plt.plot(intensities[220:280], voltages[220:280], linestyle='-', color='blue')
plt.axvline(currents[critical_current], label = f'corriente crítica: {currents[critical_current]} µA')
plt.xlabel('Corriente (µA)')
plt.ylabel('Voltaje promedio (V)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
